# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('F:\\私人文件\\清华—滴滴项目\\任务一的微博数据集\\时间序列\\司机迟到2时间序列.csv')
# setting the index as date
df['date'] = pd.to_datetime(df.date,format='%Y-%m-%d')
#df.index = df['date']


# 这两行代码解决 plt 中文显示的问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(16,8))
plt.title('各事件综合民众情绪反应——积极和消极')
plt.plot(df['time'],df['count'],label='积极')
# plt.plot(df['date'],df['negative'],label='消极')
#
# #_x_ticks = ["10点{}分".format(i) for i in x if i<60]
# x = range(0,7*24)
# x_ticks = ["{}小时".format(i) for i in x if i<600]
# plt.xticks(df['date'],x_ticks[::24])

plt.legend(loc=2)

plt.show()
